# %% [markdown]
# <h1><center><font color = purple>Super Assignment</font></center></h1>

# %% [markdown]
# import numpy as np
#
# n = int(input("Enter number of data points :"))
#
# x = np.zeros((n))
# y = np.zeros((n))
#
# print("Enter data for X and Y :")
# for i in range(n):
#     x[i]= float(input("x["+str(i)+"]="))
#     y[i]= float(input("y["+str(i)+"]="))
# xp = float(input("Enter Interpolation point :"))
# yp= 0
#
# for i in range(n):
#     p = 1
#     for j in range(n):
#         if i!=j:
#             p = p*(xp -x[j])/(x[i]-x[j])
#     yp = yp + p*y[i]
# print("Interpolated value at %.3f is %.3f. "%(xp,yp))

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objs as go
import pandas as pd
from datetime import datetime, timedelta
import folium

import datetime
import numpy as np

# %%
import dash
import dash_bootstrap_components as dbc
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import plotly.express as px

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
from IPython.core.display import display, HTML

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import folium
import plotly.graph_objects as go
import seaborn as sns
import ipywidgets as widgets

# %%
confirmed = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
death = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv'
recovered = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv'

# %%
dfc = pd.read_csv(confirmed)
dfd = pd.read_csv(death)
dfr = pd.read_csv(recovered)

# %%
#Calculating for New Positive Cases per day
ban=pd.read_csv('E:/bangladesh.csv')
confirmed=ban["Confirmed"]
active_day=[0]*len(confirmed)
active_day[0]=confirmed[0]
for i in range(1,len(confirmed)):
    active_day[i]=confirmed[i]-confirmed[i-1]
new_cases= pd.DataFrame(data=active_day, index=None, columns=["New_Cases"])
#Calculating for New Deaths Cases per day
deaths=ban["Deaths"]
deaths_day=[0]*len(deaths)
deaths_day[0]=deaths[0]
for i in range(1,len(deaths)):
    deaths_day[i]=deaths[i]-deaths[i-1]
new_deaths= pd.DataFrame(data=deaths_day, index=None, columns=["New_Deaths"])
#Calculating for New Recovered Cases per day
recovered=ban["Recovered"]
recovered_day=[0]*len(recovered)
recovered_day[0]=recovered[0]
for i in range(1,len(recovered)):
    recovered_day[i]=recovered[i]-recovered[i-1]
new_recovered= pd.DataFrame(data=recovered_day, index=None, columns=["New_Recovered"])
#Calculating for New Active Cases per day

active=ban["Active"]
active_day=[0]*len(active)
active_day[0]=active[0]
for i in range(1,len(active)):
    active_day[i]=active[i]-active[i-1]
nnew_active= pd.DataFrame(data=active_day, index=None, columns=["New_Active"])
new_active=np.abs(nnew_active)
ban = pd.concat([ban,new_cases,new_deaths,new_recovered,new_active], axis=1)

def new_graph_ban():
    
    x1 = pd.to_datetime(ban['Date'])
    
    fig = go.Figure([
       
    
            go.Scatter(x=x1, y=ban['New_Cases'], name='Confirmed',mode='markers'),
            go.Scatter(x=x1, y=ban['New_Deaths'], name='Death',mode='markers'),
            go.Scatter(x=x1, y=ban['New_Recovered'], name='Recovered',mode='markers'),
            go.Scatter(x=x1, y=ban['New_Active'], name='Active',mode='markers')
    ])  
        
   
    return fig

# %%
bhu=pd.read_csv('E:/bhutan.csv')
confirmed=bhu["Confirmed"]
active_day=[0]*len(confirmed)
active_day[0]=confirmed[0]
for i in range(1,len(confirmed)):
    active_day[i]=confirmed[i]-confirmed[i-1]
new_cases= pd.DataFrame(data=active_day, index=None, columns=["New_Cases"])
#Calculating for New Deaths Cases per day
deaths=bhu["Deaths"]
deaths_day=[0]*len(deaths)
deaths_day[0]=deaths[0]
for i in range(1,len(deaths)):
    deaths_day[i]=deaths[i]-deaths[i-1]
new_deaths= pd.DataFrame(data=deaths_day, index=None, columns=["New_Deaths"])
#Calculating for New Recovered Cases per day
recovered=bhu["Recovered"]
recovered_day=[0]*len(recovered)
recovered_day[0]=recovered[0]
for i in range(1,len(recovered)):
    recovered_day[i]=recovered[i]-recovered[i-1]
new_recovered= pd.DataFrame(data=recovered_day, index=None, columns=["New_Recovered"])
#Calculating for New Active Cases per day
active=bhu["Active"]
active_day=[0]*len(active)
active_day[0]=active[0]
for i in range(1,len(active)):
    active_day[i]=active[i]-active[i-1]
nnew_active= pd.DataFrame(data=active_day, index=None, columns=["New_Active"])
new_active=np.abs(nnew_active)
bhu = pd.concat([bhu,new_cases,new_deaths,new_recovered,new_active], axis=1)


def new_graph_bhu():
    
    x1 = pd.to_datetime(bhu['Date'])
    
    fig = go.Figure([
       
    
            go.Scatter(x=x1, y=bhu['New_Cases'], name='Confirmed',mode='markers'),
            go.Scatter(x=x1, y=bhu['New_Deaths'], name='Death',mode='markers'),
            go.Scatter(x=x1, y=bhu['New_Recovered'], name='Recovered',mode='markers'),
            go.Scatter(x=x1, y=bhu['New_Active'], name='Active',mode='markers')
    ])  
        
   
    return fig

# %%
#Calculating for New Positive Cases per day
ind=pd.read_csv('E:/india.csv')
confirmed=ind["Confirmed"]
active_day=[0]*len(confirmed)
active_day[0]=confirmed[0]
for i in range(1,len(confirmed)):
    active_day[i]=confirmed[i]-confirmed[i-1]
new_cases= pd.DataFrame(data=active_day, index=None, columns=["New_Cases"])
#Calculating for New Deaths Cases per day
deaths=ind["Deaths"]
deaths_day=[0]*len(deaths)
deaths_day[0]=deaths[0]
for i in range(1,len(deaths)):
    deaths_day[i]=deaths[i]-deaths[i-1]
new_deaths= pd.DataFrame(data=deaths_day, index=None, columns=["New_Deaths"])
#Calculating for New Recovered Cases per day
recovered=ind["Recovered"]
recovered_day=[0]*len(recovered)
recovered_day[0]=recovered[0]
for i in range(1,len(recovered)):
    recovered_day[i]=recovered[i]-recovered[i-1]
new_recovered= pd.DataFrame(data=recovered_day, index=None, columns=["New_Recovered"])
#Calculating for New Active Cases per day
active=ind["Active"]
active_day=[0]*len(active)
active_day[0]=active[0]
for i in range(1,len(active)):
    active_day[i]=active[i]-active[i-1]
nnew_active= pd.DataFrame(data=active_day, index=None, columns=["New_Active"])
new_active=np.abs(nnew_active)
ind = pd.concat([ind,new_cases,new_deaths,new_recovered,new_active], axis=1)



def new_graph_ind():
    
    x1 = pd.to_datetime(ind['Date'])
    
    fig = go.Figure([
       
    
            go.Scatter(x=x1, y=ind['New_Cases'], name='Confirmed',mode='markers'),
            go.Scatter(x=x1, y=ind['New_Deaths'], name='Death',mode='markers'),
            go.Scatter(x=x1, y=ind['New_Recovered'], name='Recovered',mode='markers'),
            go.Scatter(x=x1, y=ind['New_Active'], name='Active',mode='markers')  ])  
        
   
    return fig

# %%
#Calculating for New Positive Cases per day
mal=pd.read_csv('E:/maldives.csv')
confirmed=mal["Confirmed"]
active_day=[0]*len(confirmed)
active_day[0]=confirmed[0]
for i in range(1,len(confirmed)):
    active_day[i]=confirmed[i]-confirmed[i-1]
new_cases= pd.DataFrame(data=active_day, index=None, columns=["New_Cases"])
#Calculating for New Deaths Cases per day
deaths=mal["Deaths"]
deaths_day=[0]*len(deaths)
deaths_day[0]=deaths[0]
for i in range(1,len(deaths)):
    deaths_day[i]=deaths[i]-deaths[i-1]
new_deaths= pd.DataFrame(data=deaths_day, index=None, columns=["New_Deaths"])
#Calculating for New Recovered Cases per day
recovered=mal["Recovered"]
recovered_day=[0]*len(recovered)
recovered_day[0]=recovered[0]
for i in range(1,len(recovered)):
    recovered_day[i]=recovered[i]-recovered[i-1]
new_recovered= pd.DataFrame(data=recovered_day, index=None, columns=["New_Recovered"])
#Calculating for New Active Cases per day
active=mal["Active"]
active_day=[0]*len(active)
active_day[0]=active[0]
for i in range(1,len(active)):
    active_day[i]=active[i]-active[i-1]
nnew_active= pd.DataFrame(data=active_day, index=None, columns=["New_Active"])
new_active=np.abs(nnew_active)
mal = pd.concat([mal,new_cases,new_deaths,new_recovered,new_active], axis=1)



def new_graph_mal():
    
    x1 = pd.to_datetime(mal['Date'])
    
    fig = go.Figure([
       
    
            go.Scatter(x=x1, y=mal['New_Cases'], name='Confirmed',mode='markers'),
            go.Scatter(x=x1, y=mal['New_Deaths'], name='Death',mode='markers'),
            go.Scatter(x=x1, y=mal['New_Recovered'], name='Recovered',mode='markers'),
            go.Scatter(x=x1, y=mal['New_Active'], name='Active',mode='markers')  ])  
        
   
    return fig

# %%
#Calculating for New Positive Cases per day
nep=pd.read_csv('E:/nepal.csv')
confirmed=nep["Confirmed"]
active_day=[0]*len(confirmed)
active_day[0]=confirmed[0]
for i in range(1,len(confirmed)):
    active_day[i]=confirmed[i]-confirmed[i-1]
new_cases= pd.DataFrame(data=active_day, index=None, columns=["New_Cases"])
#Calculating for New Deaths Cases per day
deaths=nep["Deaths"]
deaths_day=[0]*len(deaths)
deaths_day[0]=deaths[0]
for i in range(1,len(deaths)):
    deaths_day[i]=deaths[i]-deaths[i-1]
new_deaths= pd.DataFrame(data=deaths_day, index=None, columns=["New_Deaths"])
#Calculating for New Recovered Cases per day
recovered=nep["Recovered"]
recovered_day=[0]*len(recovered)
recovered_day[0]=recovered[0]
for i in range(1,len(recovered)):
    recovered_day[i]=recovered[i]-recovered[i-1]
new_recovered= pd.DataFrame(data=recovered_day, index=None, columns=["New_Recovered"])
#Calculating for New Active Cases per day
active=nep["Active"]
active_day=[0]*len(active)
active_day[0]=active[0]
for i in range(1,len(active)):
    active_day[i]=active[i]-active[i-1]
nnew_active= pd.DataFrame(data=active_day, index=None, columns=["New_Active"])
new_active=np.abs(nnew_active)
nep = pd.concat([nep,new_cases,new_deaths,new_recovered,new_active], axis=1)



def new_graph_nep():
    
    x1 = pd.to_datetime(nep['Date'])
    
    fig = go.Figure([
       
    
            go.Scatter(x=x1, y=nep['New_Cases'], name='Confirmed',mode='markers'),
            go.Scatter(x=x1, y=nep['New_Deaths'], name='Death',mode='markers'),
            go.Scatter(x=x1, y=nep['New_Recovered'], name='Recovered',mode='markers'),
            go.Scatter(x=x1, y=nep['New_Active'], name='Active',mode='markers')  ])  
        
   
    return fig

# %%
pak=pd.read_csv('E:/pakistan.csv')

#Calculating for New Positive Cases per day
confirmed=pak["Confirmed"]
active_day=[0]*len(confirmed)
active_day[0]=confirmed[0]
for i in range(1,len(confirmed)):
    active_day[i]=confirmed[i]-confirmed[i-1]
new_cases= pd.DataFrame(data=active_day, index=None, columns=["New_Cases"])
#Calculating for New Deaths Cases per day
deaths=pak["Deaths"]
deaths_day=[0]*len(deaths)
deaths_day[0]=deaths[0]
for i in range(1,len(deaths)):
    deaths_day[i]=deaths[i]-deaths[i-1]
new_deaths= pd.DataFrame(data=deaths_day, index=None, columns=["New_Deaths"])
#Calculating for New Recovered Cases per day
recovered=pak["Recovered"]
recovered_day=[0]*len(recovered)
recovered_day[0]=recovered[0]
for i in range(1,len(recovered)):
    recovered_day[i]=recovered[i]-recovered[i-1]
new_recovered= pd.DataFrame(data=recovered_day, index=None, columns=["New_Recovered"])
#Calculating for New Active Cases per day
active=pak["Active"]
active_day=[0]*len(active)
active_day[0]=active[0]
for i in range(1,len(active)):
    active_day[i]=active[i]-active[i-1]
nnew_active= pd.DataFrame(data=active_day, index=None, columns=["New_Active"])
new_active=np.abs(nnew_active)
pak = pd.concat([pak,new_cases,new_deaths,new_recovered,new_active], axis=1)



def new_graph_pak():
    
    x1 = pd.to_datetime(pak['Date'])
    
    fig = go.Figure([
       
    
            go.Scatter(x=x1, y=pak['New_Cases'], name='Confirmed',mode='markers'),
            go.Scatter(x=x1, y=pak['New_Deaths'], name='Death',mode='markers'),
            go.Scatter(x=x1, y=pak['New_Recovered'], name='Recovered',mode='markers'),
            go.Scatter(x=x1, y=pak['New_Active'], name='Active',mode='markers')  ])  
        
   
    return fig

# %%
#Calculating for New Positive Cases per day
sri=pd.read_csv('E:/srilanka.csv')
confirmed=sri["Confirmed"]
active_day=[0]*len(confirmed)
active_day[0]=confirmed[0]
for i in range(1,len(confirmed)):
    active_day[i]=confirmed[i]-confirmed[i-1]
new_cases= pd.DataFrame(data=active_day, index=None, columns=["New_Cases"])
#Calculating for New Death Cases per day
deaths=sri["Deaths"]
deaths_day=[0]*len(deaths)
deaths_day[0]=deaths[0]
for i in range(1,len(deaths)):
    deaths_day[i]=deaths[i]-deaths[i-1]
new_deaths= pd.DataFrame(data=deaths_day, index=None, columns=["New_Deaths"])
#Calculating for New Recovered Cases per day
recovered=sri["Recovered"]
recovered_day=[0]*len(recovered)
recovered_day[0]=recovered[0]
for i in range(1,len(recovered)):
    recovered_day[i]=recovered[i]-recovered[i-1]
new_recovered= pd.DataFrame(data=recovered_day, index=None, columns=["New_Recovered"])
#Calculating for New Active Cases per day
active=sri["Active"]
active_day=[0]*len(active)
active_day[0]=active[0]
for i in range(1,len(active)):
    active_day[i]=active[i]-active[i-1]
nnew_active= pd.DataFrame(data=active_day, index=None, columns=["New_Active"])
new_active=np.abs(nnew_active)
sri = pd.concat([sri,new_cases,new_deaths,new_recovered,new_active], axis=1)



def new_graph_sri():
    
    x1 = pd.to_datetime(sri['Date'])
    
    fig = go.Figure([
       
    
            go.Scatter(x=x1, y=sri['New_Cases'], name='Confirmed',mode='markers'),
            go.Scatter(x=x1, y=sri['New_Deaths'], name='Death',mode='markers'),
            go.Scatter(x=x1, y=sri['New_Recovered'], name='Recovered',mode='markers'),
            go.Scatter(x=x1, y=sri['New_Active'], name='Active',mode='markers')  ])  
        
   
    return fig

# %%
child14= html.Div([
   
    dbc.Row(
                [                
                    
                    dbc.Col(dcc.Graph(id='graphw1',figure=new_graph_pak()),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }), 
                       

                ],   
            ),
   
           

])

# %%
child_ban= html.Div([
   
    dbc.Row(
                [                
                    
                    dbc.Col(dcc.Graph(id='graphw1',figure=new_graph_ban()),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }), 
                       

                ],   
            ),
   
           

])

# %%
child_bhu= html.Div([
   
    dbc.Row(
                [                
                    
                    dbc.Col(dcc.Graph(id='graphw1',figure=new_graph_bhu()),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }), 
                       

                ],   
            ),
   
           

])

# %%
child_ind= html.Div([
   
    dbc.Row(
                [                
                    
                    dbc.Col(dcc.Graph(id='graphw1',figure=new_graph_ind()),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }), 
                       

                ],   
            ),
   
           

])

# %%
child_mal= html.Div([
   
    dbc.Row(
                [                
                    
                    dbc.Col(dcc.Graph(id='graphw1',figure=new_graph_mal()),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }), 
                       

                ],   
            ),
   
           

])

# %%
child_nep= html.Div([
   
    dbc.Row(
                [                
                    
                    dbc.Col(dcc.Graph(id='graphw1',figure=new_graph_nep()),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }), 
                       

                ],   
            ),
   
           

])

# %%
child_pak= html.Div([
   
    dbc.Row(
                [                
                    
                    dbc.Col(dcc.Graph(id='graphw1',figure=new_graph_pak()),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }), 
                       

                ],   
            ),
   
           

])

# %%
child_sri= html.Div([
   
    dbc.Row(
                [                
                    
                    dbc.Col(dcc.Graph(id='graphw1',figure=new_graph_sri()),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }), 
                       

                ],   
            ),
   
           

])

# %%
dfc
# Out:
#     Province/State      Country/Region        Lat        Long  1/22/20  \
# 0              NaN         Afghanistan  33.939110   67.709953        0
# 1              NaN             Albania  41.153300   20.168300        0
# 2              NaN             Algeria  28.033900    1.659600        0
# 3              NaN             Andorra  42.506300    1.521800        0
# 4              NaN              Angola -11.202700   17.873900        0
# ..             ...                 ...        ...         ...      ...
# 269            NaN             Vietnam  14.058324  108.277199        0
# 270            NaN  West Bank and Gaza  31.952200   35.233200        0
# 271            NaN               Yemen  15.552727   48.516388        0
# 272            NaN              Zambia -13.133897   27.849332        0
# 273            NaN            Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/1/21  4/2/21  4/3/21  \
# ...

# %%
death_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
confirmed_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
recovered_df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')

# %%
confirmed_df.columns = map(str.lower, confirmed_df.columns)
death_df.columns = map(str.lower, death_df.columns)
recovered_df.columns = map(str.lower, recovered_df.columns)

# %%
confirmed_df = confirmed_df.rename(columns={'province/state': 'state', 'country/region': 'country'})
recovered_df = confirmed_df.rename(columns={'province/state': 'state', 'country/region': 'country'})
death_df = death_df.rename(columns={'province/state': 'state', 'country/region': 'country'})

# %%
confirmed_case=dfc[dfc['Country/Region'].isin(['Bangladesh','Bhutan','India','Maldives','Nepal','Pakistan','Sri Lanka'])]
death_case=dfd[dfd['Country/Region'].isin(['Bangipcoladesh','Bhutan','India','Maldives','Nepal','Pakistan','Sri Lanka'])]
recovered_case=dfr[dfr['Country/Region'].isin(['Bangladesh','Bhutan','India','Maldives','Nepal','Pakistan','Sri Lanka'])]


confirmed_df=confirmed_df.drop(['state'], axis=1)
death_df = death_df.drop(['state'], axis=1)

# %%
def process_data(data,country='Bangladesh',window=3):
    conf_case = data
    conf_case_country = conf_case[conf_case['Country/Region']==country]
    final_dataset = conf_case_country.T[4:].sum(axis='columns').diff().rolling(window=window).mean()[40:]
    df_conf = pd.DataFrame(final_dataset,columns=['Total'])
    return df_conf

# %%
confirmed_case
# Out:
#     Province/State Country/Region        Lat       Long  1/22/20  1/23/20  \
# 20             NaN     Bangladesh  23.685000  90.356300        0        0
# 26             NaN         Bhutan  27.514200  90.433600        0        0
# 146            NaN          India  20.593684  78.962880        0        0
# 175            NaN       Maldives   3.202800  73.220700        0        0
# 190            NaN          Nepal  28.166700  84.250000        0        0
# 203            NaN       Pakistan  30.375300  69.345100        0        0
# 234            NaN      Sri Lanka   7.873054  80.771797        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...    4/1/21    4/2/21    4/3/21  \
# 20         0        0        0        0  ...    617764    624594    630277
# 26         0        0        0        0  ...       886       889       891
# 146        0        0        0        0  ...  12303131  12392260  12485509
# ...

# %%
def get_overall_total(df_conf):
    return df_conf.iloc[:,-1].sum()

conf_sub_case = get_overall_total(confirmed_case)
dead_sub_case = get_overall_total(death_case)
recv_sub_case = get_overall_total(recovered_case)
active_sub_case=conf_sub_case-(dead_sub_case+recv_sub_case)
print('Total no of Confirmed:',conf_sub_case)
print('Total no ofDead:',dead_sub_case)
print('Total no of Recovered:',recv_sub_case)
# Out:
# Total no of Confirmed: 15159767
# Total no ofDead: 188420
# Total no of Recovered: 13674167

# %%
def get_cntry_total(df_conf,country='Bangladesh'):
    return df_conf[df_conf['Country/Region']==country].iloc[:,-1].sum()

country = 'Bangladesh'
conf_country_case = get_cntry_total(confirmed_case,country)
dead_country_case = get_cntry_total(death_case,country)
recv_country_case = get_cntry_total(recovered_case,country)
print(f'{country} Confirmed:',conf_country_case)
print(f'{country} Dead:',dead_country_case)
print(f'{country} Recovered:',recv_country_case)
# Out:
# Bangladesh Confirmed: 678937
# Bangladesh Dead: 0
# Bangladesh Recovered: 572378

# %%
def fig_world_trend(country='Pakistan',window=1):
    df = process_data(data=confirmed_case,country=country,window=window)
    c =[]
    if window==1:
        yaxis_title = "Daily Cases"
    else:
        yaxis_title = "Daily Cases ({}-day MA)".format(window)
        
   
        
    fig = px.line(df, y='Total', x=df.index, title='Daily Confirmed cases trend for {}'.format(country),height=500,color_discrete_sequence =['maroon'])
    fig.update_layout(title_x=0.5,plot_bgcolor='#F0F8FF',paper_bgcolor='#F0F8FF',xaxis_title="Date",yaxis_title=yaxis_title)
    return fig

# %%
#Linear Regresssion************* Start
def process_data_case(data,country='Pakistan'):
    covid_case = data
    covid_case_country = covid_case[covid_case['Country/Region']==country]
 
    
    dates= covid_case_country.keys()
    total_cases =[]
    for i in dates :
        confirmed_sum =covid_case_country[i].sum()
        total_cases.append(confirmed_sum)
        
    n = total_cases[4:]    
    
    return n

dfvc=process_data_case(data=dfc,country='Pakistan')
dfvd=process_data_case(data=dfd,country='Pakistan')
dfvr=process_data_case(data=dfr,country='Pakistan')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
cols =dfc.keys()
date_ = dfc.loc[5,cols[4]:cols[-1]]
dates= date_.keys()
days_since_1st = np.array([i for i in range(len(dates))]).reshape(-1,1)
days_in_future = 0

future_predict = np.array([i for i in range(len(dates) + days_in_future)]).reshape(-1,1)

# %%
start = '1/22/2020'
start_date = datetime.datetime.strptime(start,'%m/%d/%Y')
future_predict_dates =[]
for i in range(len(future_predict)):
    future_predict_dates.append((start_date+datetime.timedelta(days=i)).strftime('%m/%d/%Y'))

# %%
adjusted_dates=future_predict_dates

# %%
x_train_confirmed, x_test_confirmed, y_train_confirmed, y_test_confirmed = train_test_split(days_since_1st, dfvc, test_size=0.3, shuffle=False)

# %%
linear_model = LinearRegression(normalize =True,fit_intercept=True)
linear_model.fit(x_train_confirmed,y_train_confirmed)

test_predict = linear_model.predict(x_test_confirmed)

linear_predict = linear_model.predict(future_predict)

# %%
#Linear Regression*****Confirmed case
def conf_graph_display(country='Pakistan'):
    df = process_data_case(data=dfc,country=country) 
   
    fig = go.Figure([
    go.Scatter(x=adjusted_dates, y=dfvc,name='actual', mode='markers'),
    
    go.Scatter(x=future_predict_dates, y=linear_predict, name='prediction')
    ])

    return fig
    
l1=linear_model.score(days_since_1st,dfvc)

def l_acc():
    plt.title("Accuracy of Confirmed")
    plt.pie(l1,autopct='%f%%',colors='y')     
   
    return plt.show() 
l_acc()

# %%
#Polynomial Method*****Confirmed case

from sklearn.preprocessing import PolynomialFeatures 
  
poly = PolynomialFeatures(degree = 4) 
X_poly = poly.fit_transform(days_since_1st) 
  
poly.fit(X_poly,dfvc) 
poly_reg = LinearRegression() 
poly_reg.fit(X_poly, dfvc) 


def poly_conf_graph_display(country='Pakistan'):
    df = process_data_case(data=dfc,country=country) 
   
    fig = go.Figure([
    go.Scatter(x=adjusted_dates, y=dfvc,name='actual', mode='markers'),
    
    go.Scatter(x=future_predict_dates, y=poly_reg.predict(poly.fit_transform(future_predict)), name='prediction' ,  mode='lines+markers')
    ])

    return fig


poly_conf_graph_display()
# Out:
# <div>                            <div id="7d934def-cd9b-47a9-b2d8-f0726fc5a26b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d934def-cd9b-47a9-b2d8-f0726fc5a26b")) {                    Plotly.newPlot(                        "7d934def-cd9b-47a9-b2d8-f0726fc5a26b",                        [{"mode": "markers", "name": "actual", "type": "scatter", "x": ["01/22/2020", "01/23/2020", "01/24/2020", "01/25/2020", "01/26/2020", "01/27/2020", "01/28/2020", "01/29/2020", "01/30/2020", "01/31/2020", "02/01/2020", "02/02/2020", "02/03/2020", "02/04/2020", "02/05/2020", "02/06/2020", "02/07/2020", "02/08/2020", "02/09/2020", "02/10/2020", "02/11/2020", "02/12/2020", "02/13/2020", "02/14/2020", "02/15/2020", "02/16/2020", "02/17/2020", "02/18/2020", "02/19/2020"
# ...

# %%
x_train_confirmed2, x_test_confirmed2, y_train_confirmed2, y_test_confirmed2 = train_test_split(days_since_1st, dfvc, test_size=1, shuffle=False)
from sklearn.neighbors import KNeighborsRegressor
regressor = KNeighborsRegressor(n_neighbors=1)
regressor.fit(x_train_confirmed2,y_train_confirmed2)

test_predict = regressor.predict(x_test_confirmed2)
knn_predictc = regressor.predict(future_predict)


def knn_conf_graph_display(country='Pakistan'):
    df = process_data_case(data=dfc,country=country) 
   
    fig = go.Figure([
    go.Scatter(x=adjusted_dates, y=dfvc,name='actual', mode='markers'),
    
    go.Scatter(x=future_predict_dates, y=knn_predictc, name='prediction')
    ])

    return fig



knn_conf_graph_display()
k1=regressor.score(days_since_1st,dfvc)

def k_acc():
    plt.title("Accuracy of Confirmed")
    plt.pie(k1,autopct='%f%%',colors='y')     
   
    return plt.show() 
k_acc()

# %%
x_train_confirmed3, x_test_confirmed3, y_train_confirmed3, y_test_confirmed3 = train_test_split(days_since_1st, dfvc, test_size=1, shuffle=False)
from sklearn.ensemble import RandomForestRegressor
RFReg=RandomForestRegressor()
RFReg.fit(x_train_confirmed3,y_train_confirmed3)
y_predict_rfr=RFReg.predict(x_test_confirmed3)
RFReg_predictic=RFReg.predict(future_predict)




def RFReg_conf_graph_display(country='Pakistan'):
    df = process_data_case(data=dfc,country=country) 
   
    fig = go.Figure([
    go.Scatter(x=adjusted_dates, y=dfvc,name='actual', mode='markers'),
    
    go.Scatter(x=future_predict_dates, y=RFReg_predictic, name='prediction')
    ])

    return fig



RFReg_conf_graph_display()

from sklearn import metrics


y31=RFReg.score(days_since_1st,dfvc)

def acc1():
    plt.title("Accuracy of Confirmed")
    plt.pie(y31,autopct='%f%%',colors='y')     
   
    return plt.show() 



acc1()

# %%
x_train_death, x_test_death, y_train_death, y_test_death = train_test_split(days_since_1st, dfvd, test_size=0.3, shuffle=False)

# %%
linear_model = LinearRegression(normalize =True,fit_intercept=True)
linear_model.fit(x_train_death,y_train_death)

test_predict = linear_model.predict(x_test_death)
linear_predict2 = linear_model.predict(future_predict)

# %%
def death_graph_display(country='Pakistan'):
    df = process_data_case(data=dfd,country=country) 
    
    fig = go.Figure([
    go.Scatter(x=adjusted_dates, y=dfvd,name='actual', mode='markers'),
    
    go.Scatter(x=future_predict_dates, y=linear_predict2, name='prediction')
    ])

    return fig

# %%
#Polynomial Method*****Death case

from sklearn.preprocessing import PolynomialFeatures 
  
poly1 = PolynomialFeatures(degree = 4) 
X_poly1 = poly1.fit_transform(days_since_1st) 
  
poly1.fit(X_poly1,dfvd) 
poly_reg1 = LinearRegression() 
poly_reg1.fit(X_poly1, dfvd) 


def poly_death_graph_display(country='Pakistan'):
    df = process_data_case(data=dfd,country=country) 
   
    fig = go.Figure([
    go.Scatter(x=adjusted_dates, y=dfvd,name='actual', mode='markers'),
    
    go.Scatter(x=future_predict_dates, y=poly_reg1.predict(poly1.fit_transform(future_predict)), name='prediction',mode='lines+markers')
    ])

    return fig


poly_death_graph_display()
# Out:
# <div>                            <div id="f65c5517-4676-47e1-8223-e87973dc4121" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f65c5517-4676-47e1-8223-e87973dc4121")) {                    Plotly.newPlot(                        "f65c5517-4676-47e1-8223-e87973dc4121",                        [{"mode": "markers", "name": "actual", "type": "scatter", "x": ["01/22/2020", "01/23/2020", "01/24/2020", "01/25/2020", "01/26/2020", "01/27/2020", "01/28/2020", "01/29/2020", "01/30/2020", "01/31/2020", "02/01/2020", "02/02/2020", "02/03/2020", "02/04/2020", "02/05/2020", "02/06/2020", "02/07/2020", "02/08/2020", "02/09/2020", "02/10/2020", "02/11/2020", "02/12/2020", "02/13/2020", "02/14/2020", "02/15/2020", "02/16/2020", "02/17/2020", "02/18/2020", "02/19/2020"
# ...

# %%
x_train_death2, x_test_death2, y_train_death2, y_test_death2 = train_test_split(days_since_1st, dfvd, test_size=1, shuffle=False)
from sklearn.neighbors import KNeighborsRegressor
regressor = KNeighborsRegressor(n_neighbors=5)
regressor.fit(x_train_death2,y_train_death2)

test_predict = regressor.predict(x_test_death2)
knn_predict2 = regressor.predict(future_predict)


def knn_death_graph_display(country='Pakistan'):
    df = process_data_case(data=dfd,country=country) 
   
    fig = go.Figure([
    go.Scatter(x=adjusted_dates, y=dfvd,name='actual', mode='markers'),
    
    go.Scatter(x=future_predict_dates, y=knn_predict2, name='prediction')
    ])

    return fig



knn_death_graph_display()

k2=regressor.score(days_since_1st,dfvd)

def k2_acc():
    plt.title("Accuracy of Death")
    plt.pie(k2,autopct='%f%%',colors='r')     
   
    return plt.show() 
k2_acc()

# %%
x_train_death3, x_test_death3, y_train_death3, y_test_death3 = train_test_split(days_since_1st, dfvd, test_size=1, shuffle=False)
from sklearn.ensemble import RandomForestRegressor
RFReg2=RandomForestRegressor()
RFReg2.fit(x_train_death3,y_train_death3)
y_predict_rfr=RFReg2.predict(x_test_death3)
RFReg_predictid=RFReg2.predict(future_predict)




def RFReg_death_graph_display(country='Pakistan'):
    df = process_data_case(data=dfc,country=country) 
   
    fig = go.Figure([
    go.Scatter(x=adjusted_dates, y=dfvd,name='actual', mode='markers'),
    
    go.Scatter(x=future_predict_dates, y=RFReg_predictid, name='prediction')
    ])

    return fig



RFReg_death_graph_display()
from sklearn import metrics


y3=RFReg2.score(days_since_1st,dfvd)

def acc():
    plt.title("Accuracy of Death")
    plt.pie(y3,autopct='%f%%',colors='red')     
   
    return plt.show()

# %%
x_train_recover, x_test_recover, y_train_recover, y_test_recover= train_test_split(days_since_1st, dfvr, test_size=0.3, shuffle=False)

# %%
linear_model = LinearRegression(normalize =True,fit_intercept=True)
linear_model.fit(x_train_recover,y_train_recover)

test_predict = linear_model.predict(x_test_recover)
linear_predict = linear_model.predict(future_predict)

# %%
def recovered_graph_display(country='Pakistan'):
    df = process_data_case(data=dfr,country=country) 
 
    fig = go.Figure([
    
    go.Scatter(x=adjusted_dates, y=dfvr,name='actual', mode='markers'),
    go.Scatter(x=future_predict_dates, y=linear_predict, name='prediction')
       
    ])

    return fig

# %%
#Polynomial Method*****Recovered case

from sklearn.preprocessing import PolynomialFeatures 
  
poly = PolynomialFeatures(degree = 4) 
X_poly = poly.fit_transform(days_since_1st) 
  
poly.fit(X_poly,dfvr) 
poly_reg = LinearRegression() 
poly_reg.fit(X_poly, dfvr) 


def poly_recover_graph_display(country='Pakistan'):
    df = process_data_case(data=dfr,country=country) 
   
    fig = go.Figure([
    go.Scatter(x=adjusted_dates, y=dfvr,name='actual', mode='markers'),
    
    go.Scatter(x=future_predict_dates, y=poly_reg.predict(poly.fit_transform(future_predict)), name='prediction',mode='lines+markers')
    ])

    return fig


poly_recover_graph_display()
# Out:
# <div>                            <div id="0572bc29-3bcc-4c7c-89b1-325d46d169d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0572bc29-3bcc-4c7c-89b1-325d46d169d3")) {                    Plotly.newPlot(                        "0572bc29-3bcc-4c7c-89b1-325d46d169d3",                        [{"mode": "markers", "name": "actual", "type": "scatter", "x": ["01/22/2020", "01/23/2020", "01/24/2020", "01/25/2020", "01/26/2020", "01/27/2020", "01/28/2020", "01/29/2020", "01/30/2020", "01/31/2020", "02/01/2020", "02/02/2020", "02/03/2020", "02/04/2020", "02/05/2020", "02/06/2020", "02/07/2020", "02/08/2020", "02/09/2020", "02/10/2020", "02/11/2020", "02/12/2020", "02/13/2020", "02/14/2020", "02/15/2020", "02/16/2020", "02/17/2020", "02/18/2020", "02/19/2020"
# ...

# %%
x_train_recover2, x_test_recover2, y_train_recover2, y_test_recover2 = train_test_split(days_since_1st, dfvr, test_size=1, shuffle=False)
from sklearn.neighbors import KNeighborsRegressor
regressor = KNeighborsRegressor(n_neighbors=5)
regressor.fit(x_train_recover2,y_train_recover2)

test_predict = regressor.predict(x_test_recover2)
knn_predict = regressor.predict(future_predict)


def knn_recover_graph_display(country='Pakistan'):
    df = process_data_case(data=dfr,country=country) 
   
    fig = go.Figure([
    go.Scatter(x=adjusted_dates, y=dfvr,name='actual', mode='markers'),
    
    go.Scatter(x=future_predict_dates, y=knn_predict, name='prediction', mode='lines')
    ])

    return fig



knn_recover_graph_display()

k3=regressor.score(days_since_1st,dfvr)

def k3_acc():
    plt.title("Accuracy of Recovered")
    plt.pie(k3,autopct='%f%%',colors='green')     
   
    return plt.show() 
k3_acc()

# %%
x_train_recover3, x_test_recover3, y_train_recover3, y_test_recover3= train_test_split(days_since_1st, dfvr, test_size=0.3, shuffle=False)
from sklearn.ensemble import RandomForestRegressor
RFReg3=RandomForestRegressor(n_estimators=11,random_state=0)
RFReg3.fit(x_train_recover3,y_train_recover3)
y_predict_rfr=RFReg3.predict(x_test_recover3)
RFReg_predictir=RFReg3.predict(future_predict)




def RFReg_recover_graph_display(country='Pakistan'):
    df = process_data_case(data=dfc,country=country) 
   
    fig = go.Figure([
    go.Scatter(x=adjusted_dates, y=dfvr,name='actual', mode='markers'),
    
    go.Scatter(x=future_predict_dates, y=RFReg_predictir, name='prediction')
        
        
    ])

    return fig

RFReg_recover_graph_display()
from sklearn import metrics


y32=RFReg3.score(days_since_1st,dfvr)

def acc2():
    plt.title("Accuracy Of Recovered")
    plt.pie(y32,autopct='%f%%',colors='g')     
   
    return plt.show() 
acc2()

# %%
def fig_world_trend2(country='Bangladesh',window=1):
    df = process_data(data=recovered_case,country=country,window=window)
    
    if window==1:
        yaxis_title = "Daily Cases"
    else:
        yaxis_title = "Daily Cases ({}-day MA)".format(window)
    fig = px.line(df, y='Total', x=df.index, title='Daily Recovered cases trend for {}'.format(country),height=550,color_discrete_sequence =['maroon'])
    fig.update_layout(title_x=0.5,plot_bgcolor='#F0F8FF',paper_bgcolor='#F0F8FF',xaxis_title="Date",yaxis_title=yaxis_title)
    return fig

# %%
def fig_world_trend3(country='Bangladesh',window=1):
    df = process_data(data=death_case,country=country,window=window)
  

    if window==1:
        yaxis_title = "Daily Cases"
    else:
        yaxis_title = "Daily Cases ({}-day MA)".format(window)
    fig = px.line(df, y='Total', x=df.index, title='Daily Death cases trend for {}'.format(country),height=550,color_discrete_sequence =['maroon'])
    
    fig.update_layout(title_x=0.5,plot_bgcolor='#F0F8FF',paper_bgcolor='#F0F8FF',xaxis_title="Date",yaxis_title=yaxis_title)
    return fig

# %%
external_stylesheets = [dbc.themes.BOOTSTRAP]

# %%
app = dash.Dash(__name__, external_stylesheets=external_stylesheets)
app.title = 'Covid-19 Dashboard'

# %%
colors = {
    'background': '#111111',
    'bodyColor':'#F0F8FF',
    'text': '#D3D3D3'
}
def get_page_heading_style():
    return {'backgroundColor': colors['background'],
            
           }


def get_page_heading_title():
    return (html.Img(src='https://shcc.ufl.edu/files/2020/03/ShowImage.jpeg'
                                                ,style={
                                                    'height': '250px',
                                                    'width': '100%',
                                                    
  
                                                }),html.H1(children='COVID-19 Dashboard',
                                        style={
                                        'textAlign': 'center',
                                          
                                       
                                        'color': colors['text']
                                    })  
)


def get_page_heading_subtitle():
    return html.Div(children='Visualize Covid-19 data generated from sources all over the world.',
                                         style={
                                             'textAlign':'center',
                                            'padding':'15px',
                                             
                                             'color':colors['text']
                                         })

def generate_page_header():
    main_header =  dbc.Row(
                            [
                                dbc.Col(get_page_heading_title(),md=12)
                            ],
                            align="center",
                            style=get_page_heading_style()
                        )
    subtitle_header = dbc.Row(
                            [
                                dbc.Col(get_page_heading_subtitle(),md=12)
                            ],
                            align="center",
                            style=get_page_heading_style()
                        )
    header = (main_header,subtitle_header)
    return header

# %%
def get_country_list():
    return confirmed_case['Country/Region'].unique()

def create_dropdown_list(cntry_list):
    dropdown_list = []
    for country in sorted(cntry_list):
        tmp_dict = {'label':country,'value':country}
        dropdown_list.append(tmp_dict)
    return dropdown_list

def get_country_dropdown():
    return html.Div([
                        html.Label('Select Country'),
                        dcc.Dropdown(id='my-id1',
                            options=create_dropdown_list(get_country_list()),
                            value='Bangladesh'
                        ),
                        
                    ])

def getdropdown22():
    return html.Div([
                        html.Label('Select Country'),
                        dcc.Dropdown(id='id12',
                            options=create_dropdown_list(get_country_list()),
                            value='Pakistan'
                        ),
                        
                    ])

# %%
def generate_card_content(card_header,card_value,overall_value):
    card_head_style = {'textAlign':'center','fontSize':'100%'}
    card_body_style = {'textAlign':'center','fontSize':'90%'}
    card_header = dbc.CardHeader(card_header,style=card_head_style)
    card_body = dbc.CardBody(
        [
            html.H5(f"{int(card_value):,}", className="card-title",style=card_body_style),
            html.P(
                "Sub-Continent: {:,}".format(overall_value),
                className="card-text",style={'textAlign':'center'}
            ),
        ]
    )
    card = [card_header,card_body]
    return card

# %%
def generate_cards(country='Pakistan'):
    conf_country_case = get_cntry_total(confirmed_case,country)
    dead_country_case = get_cntry_total(death_case,country)
    recv_country_case = get_cntry_total(recovered_case,country)
    active_country_case=conf_country_case-(dead_country_case+recv_country_case)
    cards = html.Div(
        [
            dbc.Row(
                [

                    dbc.Col(dbc.Card(generate_card_content("Recovered",recv_country_case,recv_sub_case), color="success", inverse=True),md=dict(size=2,offset=2)),
                    dbc.Col(dbc.Card(generate_card_content("Confirmed",conf_country_case,conf_sub_case), color="warning", inverse=True),md=dict(size=2)),
                    dbc.Col(dbc.Card(generate_card_content("Dead",dead_country_case,dead_sub_case),color="maroon", inverse=True),md=dict(size=2)),
                    dbc.Col(dbc.Card(generate_card_content("Active",active_country_case,active_sub_case),color="#FFA07A", inverse=True),md=dict(size=2)),
                ],
                className="mb-4",
            ),
        ],id='card1'
        
    )
    return cards

# %%
def get_slider():
    return html.Div([  
                        dcc.Slider(
                            id='my-slider',
                            min=1,
                            max=15,
                            step=None,
                            marks={
                                1: '1',
                                3: '3',
                                5: '5',
                                7: '1Week',
                                14: '2Weeks'
                            },
                            value=1,
                        ),
                        html.Div([html.Label('Select Moving Average Window')],style={'textAlign':'center'})
                    ])

# %%
def get_slider2():
    return html.Div([  
                        dcc.Slider(
                            id='my-slider2',
                            min=1,
                            max=15,
                            step=None,
                            marks={
                                1: '1',
                                3: '3',
                                5: '5',
                                7: '1Week',
                                14: '2Weeks'
                            },
                            value=1,
                        ),
                        html.Div([html.Label('Select Moving Average Window')],style={'textAlign':'center'})
                    ])

# %%
child= html.Div([
    dbc.Row(
                [
                    dbc.Col(get_country_dropdown(),md=dict(size=4,offset=4)),                    
                ]
                
            
            ),
            
            dbc.Row(
                [                
                     
                    
                    dbc.Col(dcc.Graph(id='graph1',figure=fig_world_trend('Pakistan')),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }),  
                    

                ],
                

            ),
            
            dbc.Row(
                [
                    dbc.Col(get_slider(),md=dict(size=4,offset=4),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }),
                    
                ],
                
            
            ),
    
])

# %%
child2= html.Div([
        
   
            dbc.Row(
                [                
                    
                    
                    dbc.Col(dcc.Graph(id='graph2',figure=fig_world_trend2('Pakistan')),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }),  
                    

                ],
                

            ),
   
        
   
    
])

# %%
child3= html.Div([
   
    dbc.Row(
                [                
                    
                    
                    dbc.Col(dcc.Graph(id='graph3',figure=fig_world_trend3('Pakistan')),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }),  
                    

                ],
                

        
            ),
   
                
            
            
                

])

# %%
def he():
    
    return html.Div([ html.Label('Select Moving Average Window')  ])

# %%
#LinearRegression**************
child9= html.Div([
    dbc.Row(
                [
                    dbc.Col(getdropdown22(),md=dict(size=4,offset=4)),                    
                ]
                
            
            ),html.Label(('                        Visualization of covid-19 confirmed cases'),style={'textAlign':'center'}),
            
    dbc.Row(
                [                
                    
                    dbc.Col(dcc.Graph(id='graph9',figure=conf_graph_display('Pakistan')),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }),  
                    

                ],
                

            ),html.Label(('                        Visualization of covid-19 death cases'),style={'textAlign':'center'}),
     dbc.Row(
                [                
                    
                    dbc.Col(dcc.Graph(id='graph9',figure=death_graph_display('Pakistan')),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }),  
                    

                ],
                

            ),html.Label(('                        Visualization of covid-19 recovered cases'),style={'textAlign':'center'}),
    
     dbc.Row(
                [                
                    
                    dbc.Col(dcc.Graph(id='graph9',figure=recovered_graph_display('Pakistan')),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }),  
                    

                ],
                

            ),
            
           
    
])

# %%
#Polynominal Regression**************
child10= html.Div([
    dbc.Row(
                [
                    dbc.Col(getdropdown22(),md=dict(size=4,offset=4)),                    
                ]
                
            
            ),html.Label(('                        Visualization of covid-19 confirmed cases'),style={'textAlign':'center'}),
            
    dbc.Row(
                [                
                    
                    dbc.Col(dcc.Graph(id='graph10',figure=poly_conf_graph_display('Pakistan')),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }),  
                    

                ],
                

            ),html.Label(('                        Visualization of covid-19 death cases'),style={'textAlign':'center'}),
     dbc.Row(
                [                
                    
                    dbc.Col(dcc.Graph(id='graph10',figure=poly_death_graph_display('Pakistan'),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }),  
                    

                           ),],
                

            ),html.Label(('                        Visualization of covid-19 recovered cases'),style={'textAlign':'center'}),
    
     dbc.Row(
                [                
                    
                    dbc.Col(dcc.Graph(id='graph10',figure=poly_recover_graph_display('Pakistan')),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }),  
                    

                ],
                

            ),
            
           
    
])

# %%
#Knn Regression**************
child11= html.Div([
    dbc.Row(
                [
                    dbc.Col(getdropdown22(),md=dict(size=4,offset=4)),                    
                ]
                
            
            ),html.Label(('                        Visualization of covid-19 confirmed cases'),style={'textAlign':'center'}),
            
    dbc.Row(
                [                
                    
                    dbc.Col(dcc.Graph(id='graph10',figure=knn_conf_graph_display('Pakistan')),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }),  
                    

                ],
                

            ),html.Label(('                        Visualization of covid-19 death cases'),style={'textAlign':'center'}),
     dbc.Row(
                [                
                    
                    dbc.Col(dcc.Graph(id='graph10',figure=knn_death_graph_display('Pakistan'),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }),  
                    

                           ),],
                

            ),html.Label(('                        Visualization of covid-19 recovered cases'),style={'textAlign':'center'}),
    
     dbc.Row(
                [                
                    
                    dbc.Col(dcc.Graph(id='graph10',figure=knn_recover_graph_display('Pakistan')),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }),  
                    

                ],
                

            ),
            
           
    
])

# %%
#Knn Regression**************
child12= html.Div([
    dbc.Row(
                [
                    dbc.Col(getdropdown22(),md=dict(size=4,offset=4)),                    
                ]
                
            
            ),html.Label(('                        Visualization of covid-19 confirmed cases'),style={'textAlign':'center'}),
            
    dbc.Row(
                [                
                    
                    dbc.Col(dcc.Graph(id='graph10',figure=RFReg_conf_graph_display('Pakistan')),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }),  
                    

                ],
                

            ),html.Label(('                        Visualization of covid-19 death cases'),style={'textAlign':'center'}),
     dbc.Row(
                [                
                    
                    dbc.Col(dcc.Graph(id='graph10',figure=RFReg_death_graph_display('Pakistan'),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }),  
                    

                           ),],
                

            ),html.Label(('                        Visualization of covid-19 recovered cases'),style={'textAlign':'center'}),
    
     dbc.Row(
                [                
                    
                    dbc.Col(dcc.Graph(id='graph10',figure=RFReg_recover_graph_display('Pakistan')),style={
                                             
                                            'padding':'15px',
                                             
                                            
                    }),  
                    

                ],
                

            ),
            
           
    
])

# %%
child_covid= html.Div([
   
    #html.H3(children='It can take up to 14 days for symptoms of coronavirus to appear. The main symptoms to look out for are:'),
    dbc.Row(
                [                
                    
                    dbc.Col(
                           [
                               
                            dbc.Row([html.H2('PRECAUTIONS ')],style={'color':'red',"padding": "16px 16px"}),
                            dbc.Row([html.H4('Ways to prevent the disease')],style={'color':'Black',"padding": "16px 16px"}),
                            dbc.Row([html.Label('Protect yourself and others around you by knowing the facts and taking appropriate precautions. Follow advice provided by your local health authority.'),
                                    ],style={'color':'#493e32',
                     "padding": "16px 16px",
                    }),
                            
                            dbc.Row([html.Label('To prevent the spread of COVID-19:'),
                                    html.Li('Clean your hands often. Use soap and water, or an alcohol-based hand rub.'),
                                    html.Li('Maintain a safe distance from anyone who is coughing or sneezing.'),
                                     html.Li('Wear a mask when physical distancing is not possible.'),
                                     html.Li('Don’t touch your eyes, nose or mouth.'),
                                     html.Li('Cover your nose & mouth with your bent elbow or a tissue when you cough/sneeze.'),
                                     html.Li('Stay home if you feel unwell.'),
                                    html.Li('If you have a fever, cough and difficulty breathing, seek medical attention.'),
                                    ],style={'color':'black',
                     "padding": "16px 16px","font-size": "16px"}),  
                               dbc.Row([html.Label('Calling in advance allows your healthcare provider to quickly direct you to the right health facility. This protects you, and prevents the spread of viruses and other infections.'),]
                                   ,style={'color':'black',
                     "padding": "16px 16px"}),
                          
                               

                           ],style={
                     "width": "850px"}
                        
                    ),
                    dbc.Col(
                           
                            
                           html.Img(src='https://raw.githubusercontent.com/danicircle/pic/master/mop.jpg'),md=dict(offset=0),style={'color':'black',
                     "padding": "16px 16px"}

                           
                        
                    ),
                   

                ],   
            ),
   
   
   
           

])

# %%
child_covid1= html.Div([
                              

    dbc.Row(html.H2('Corona Virus SYMPTOMS'),style={'color':'red',
                     "padding": "16px 16px"
                    }),
    dbc.Row([html.Label('It can take up to 14 days for symptoms of coronavirus to appear. The main symptoms to look out for are:')
            
            ],style={'color':'#493e32',
                     "padding": "16px 16px"
                    }),
    #html.H3(children='It can take up to 14 days for symptoms of coronavirus to appear. The main symptoms to look out for are:'),
    dbc.Row(
                [                
                    
                     dbc.Col([html.Img(src='https://covid.gov.pk/v2/img/symptom-a.png'),html.Label(' Fever – this means you feel hot to touch on your chest or back (you do not need to measure your temperature). It is a common sign and also may appear in 2-10 days if you affected.'),
                             ]),
                     dbc.Col([html.Img(src='https://covid.gov.pk/v2/img/symptom-b.png'),html.Label(' Coughing – this means coughing a lot for more than an hour, or 3 or more coughing episodes in 24 hours (if you usually have a cough, it may be worse than usual).')
                             ]),
                     dbc.Col([html.Img(src='https://covid.gov.pk/v2/img/symptom-c.png'),html.Label(' Shortness Of Breath – Around 1 out of every 6 people who get COVID-19 becomes seriously ill and develops difficulty breathing or shortness of breath.')
                             ]),

                ],   
            ),
   
   
   
           

])

# %%
#linearRegression
def generate_layout2():
   
    layout = dbc.Container(
        [
            html.Hr(),
       
            child9,
            html.Hr()
       
        
                      
           
        ],fluid=True,style={'backgroundColor': colors['bodyColor']}
    )
    return layout

# %%
#PolynominalRegression
def generate_layout3():
   
    layout = dbc.Container(
        [
            html.Hr(),
       
            child10,
            html.Hr(),
         
        
                      
           
        ],fluid=True,style={'backgroundColor': colors['bodyColor']}
    )
    return layout

# %%
#PolynominalRegression
def generate_layout4():
   
    layout = dbc.Container(
        [
            html.Hr(),
      
            child11,
            html.Hr(),
             
        
                      
           
        ],fluid=True,style={'backgroundColor': colors['bodyColor']}
    )
    return layout

# %%
#PolynominalRegression
def generate_layout5():
   
    layout = dbc.Container(
        [
            html.Hr(),
       
            child12,
            html.Hr(),
            lop()
       
        
                      
           
        ],fluid=True,style={'backgroundColor': colors['bodyColor']}
    )
    return layout

# %%
def banCases():
   
    layout = dbc.Container(
        [
            html.Hr(),
      
           child_ban,
            html.Hr(),
             
        
                      
           
        ],fluid=True,style={'backgroundColor': colors['bodyColor']}
    )
    return layout

# %%
def bhuCases():
   
    layout = dbc.Container(
        [
            html.Hr(),
      
           child_bhu,
            html.Hr(),
             
        
                      
           
        ],fluid=True,style={'backgroundColor': colors['bodyColor']}
    )
    return layout

# %%
def indCases():
   
    layout = dbc.Container(
        [
            html.Hr(),
      
           child_ind,
            html.Hr(),
             
        
                      
           
        ],fluid=True,style={'backgroundColor': colors['bodyColor']}
    )
    return layout

# %%
def malCases():
   
    layout = dbc.Container(
        [
            html.Hr(),
      
           child_mal,
            html.Hr(),
             
        
                      
           
        ],fluid=True,style={'backgroundColor': colors['bodyColor']}
    )
    return layout

# %%
def nepCases():
   
    layout = dbc.Container(
        [
            html.Hr(),
      
           child_nep,
            html.Hr(),
             
        
                      
           
        ],fluid=True,style={'backgroundColor': colors['bodyColor']}
    )
    return layout

# %%
def pakCases():
   
    layout = dbc.Container(
        [
            html.Hr(),
      
           child_pak,
            html.Hr(),
             
        
                      
           
        ],fluid=True,style={'backgroundColor': colors['bodyColor']}
    )
    return layout

# %%
def sriCases():
   
    layout = dbc.Container(
        [
            html.Hr(),
      
           child_sri,
            html.Hr(),
             
        
                      
           
        ],fluid=True,style={'backgroundColor': colors['bodyColor']}
    )
    return layout

# %%
@app.callback(
    [Output(component_id='graph9',component_property='figure')], #overall card numbers
    [Input(component_id='id12',component_property='value')] #slider
)

def update_output_div1(input_value9):
    return conf_graph_display(input_value9)

#linearRegression End ****************

# %%
@app.callback(
    [Output(component_id='graph10',component_property='figure')], #overall card numbers
    [Input(component_id='id12',component_property='value')] #slider
)

def update_output_div10(input_value10):
    return poly_conf_graph_display(input_value10)

#Polynominal End ****************

# %%
def generate_layout():
    page_header = generate_page_header()
   
    layout = dbc.Container(
        [
            page_header[0],
            page_header[1],
            html.Hr(),
            generate_cards(),
            html.Hr(),
            


            child,
            html.Hr(), 
            child2,
            html.Hr(), 
            child3,
            html.Hr(),
            #drowp,
            html.Hr(),
            child14,
            html.Hr(),
             map_view,
              html.Hr(),
            child_covid1, 
            html.Hr(),
            
            child_covid, 
            html.Hr(),
           
        ],fluid=True,style={'backgroundColor': colors['bodyColor']}
    )
    return layout

# %%
#app.layout = generate_layout()

# %%
@app.callback(
    [Output(component_id='graph1',component_property='figure'),#line chart
     Output(component_id='card1',component_property='children')], #overall card numbers
    [Input(component_id='my-id1',component_property='value'), #dropdown
     Input(component_id='my-slider',component_property='value')] #slider
)

def update_output_div(input_value1,input_value2):
    
    return fig_world_trend(input_value1,input_value2),generate_cards(input_value1)

# %%
@app.callback(
    [Output(component_id='graph2',component_property='figure'),#line chart
    ], #overall card numbers
    [Input(component_id='my-id12',component_property='value'), #dropdown
     Input(component_id='my-slider2',component_property='value')] #slider
)

def update_output_div1(input_value1,input_value2):
    
    return fig_world_trend2(input_value1,input_value2)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from matplotlib import dates as mpl_dates
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error
import time
import datetime

import warnings
warnings.filterwarnings('ignore')

# %%
ban=pd.read_csv('E:/bangladesh.csv')

# %%
dates= ban.Date.keys()
ban['Date'] = np.array([i for i in range(len(dates))]).reshape(-1,1)

x=ban.loc[:,['Date']]
y=ban.loc[:,['Confirmed']]

# %%
plt.plot(x,y)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
confirmed_c = pd.read_csv('E:/confirmed.csv')
deaths_c =pd.read_csv('E:/deaths.csv' )  
recovered_c =pd.read_csv('E:/recovered.csv' )

# %%
cols =confirmed_c.keys()
cols= deaths_c.keys()
cols=recovered_c.keys()
confirmed = confirmed_c.loc[5,cols[4]:cols[-1]]
deaths = deaths_c.loc[5,cols[4]:cols[-1]]
recovered = recovered_c.loc[5,cols[4]:cols[-1]]

# %%
#Bangladesh
dates= confirmed.keys()
sub_cases =[]
total_deaths =[]
total_recovered =[]

for i in dates :
    confirmed_sum = confirmed[i].sum()
    deaths_sum = deaths[i].sum()
    recovered_sum = recovered[i].sum()
    sub_cases.append(confirmed_sum)
    total_deaths.append(deaths_sum)
    total_recovered.append(recovered_sum)

# %%
days_since_1st = np.array([i for i in range(len(dates))]).reshape(-1,1)
total_deaths = np.array(total_deaths).reshape(-1,1)
total_recovered = np.array(total_recovered).reshape(-1,1)

# %%
days_in_future = 7
future_predict = np.array([i for i in range(len(dates) + days_in_future)]).reshape(-1,1)
adjusted_dates = future_predict[:-7]

# %%
start = '1/22/2020'
start_date = datetime.datetime.strptime(start,'%m/%d/%Y')
future_predict_dates =[]
for i in range(len(future_predict)):
    future_predict_dates.append((start_date+datetime.timedelta(days=i)).strftime('%m/%d/%Y'))

# %%
def linear_layout():
 
    
    layout = dbc.Container(
        [
            html.Hr(),
           
       
             
            html.Hr(),              
           
        ],fluid=True,style={'backgroundColor': colors['bodyColor']}
    )
    return layout

# %%
# the style arguments for the sidebar. We use position:fixed and a fixed width
SIDEBAR_STYLE = {
    "position": "fixed",
    "top": 0,
    "left": 0,
    "bottom": 0,
    "width": "256px",
    "padding": "16px 16px",
    "background-color": "#f5faff",
}

# the styles for the main content position it to the right of the sidebar and
# add some padding.
CONTENT_STYLE = {
    "margin-left": "256px",
    "margin-right": "5px",
    "padding": "10px"
   
}

sidebar = html.Div(
    [
        html.H2("My Prediction", className="display-6"),
        html.Hr(),
        html.P(
            "Covid-19 Dashboard", className="lead"
        ),
        dbc.Nav(
            [
                dbc.NavLink("Dashboard", href="/", active="exact"),
                dbc.NavLink("LinearRegression", href="/page-1", active="exact"),
                dbc.NavLink("PolynominalRegression", href="/page-2", active="exact"),
                dbc.NavLink("KnnRegression", href="/page-3", active="exact"),
                dbc.NavLink("RFRegression", href="/page-4", active="exact"),
                dbc.NavLink("Bangladesh", href="/bangladesh", active="exact"),
                dbc.NavLink("Bhutan", href="/bhutan", active="exact"),
                dbc.NavLink("India", href="/india", active="exact"),
                dbc.NavLink("Maldives", href="/maldives", active="exact"),
                dbc.NavLink("Nepal", href="/nepal", active="exact"),
                dbc.NavLink("Pakistan", href="/pakistan", active="exact"),
                dbc.NavLink("Sri lanka", href="/sri-lanka", active="exact"),
            ],
            vertical=True,
            pills=True,
        ),
    ],
    style=SIDEBAR_STYLE,
)

content = html.Div(id="page-content", style=CONTENT_STYLE)

app.layout = html.Div([dcc.Location(id="url"), sidebar, content])


@app.callback(Output("page-content", "children"), [Input("url", "pathname")])
def render_page_content(pathname):
    if pathname == "/":
        return generate_layout()
    elif pathname == "/page-1":
        return generate_layout2()
    elif pathname == "/page-2":
        return generate_layout3()
    elif pathname == "/page-3":
        return generate_layout4()
    elif pathname == "/page-4":
        return generate_layout5()
    elif pathname == "/bangladesh":
        return banCases()
    elif pathname == "/bhutan":
        return bhuCases()
    elif pathname == "/india":
        return indCases()
    elif pathname == "/maldives":
        return malCases()
    elif pathname == "/nepal":
        return nepCases()
    elif pathname == "/pakistan":
        return pakCases()
    elif pathname == "/sri-lanka":
        return sriCases()
       
       

    # If the user tries to reach a different page, return a 404 message
    return dbc.Jumbotron(
        [
            html.H1("404: Not found", className="text-danger"),
            html.Hr(),
            html.P(f"The pathname {pathname} was not recognised..."),
        ]
    )

# %%
death_case.iloc[:,-1].sum()
# Out:
# 188420

# %%
from folium.plugins import MarkerCluster
def mouse():
    world_map = folium.Map(location=[20,80], tiles="cartodbpositron", zoom_start=4, max_zoom = 6, min_zoom = 2)
    m = folium.Map(location=[20,80], tiles="cartodbpositron", zoom_start=4, max_zoom = 6, min_zoom = 2)
    folium.Marker(location=[30.375300,69.345100],popup='heelo').add_to(m)
    folium.Marker(location=[20.593684,78.962880	],popup='heelo').add_to(m)
    for i in range(0,len(confirmed_case)):
        folium.Circle(
            location=[confirmed_case.iloc[i]['Lat'], confirmed_case.iloc[i]['Long']],
            fill=True,
            radius=(int((np.log2(confirmed_case.iloc[i,-1]+1.00001)))+0.01)*20000,
            color='#DC143C',
            fill_color='#F08080',
       
            
            
            tooltip = "<div style='padding : 4px; background-color: #d5d2be; color: white;'>"+
             
                   
                    "<h3 style='text-align:center;font-weight: bold'>"+confirmed_case.iloc[i]['Country/Region']+  "</h3>"+
                    "<hr style='margin:10px;color: white;'>"+
          
                    "<ul style='color: white;;list-style-type:circle;align-item:left;padding-left:25px;padding-right:25px'>"+
                        "<li style='color: yellow;font-size: 1.3em;'>Confirmed: "+str(confirmed_case.iloc[i,-1])+"</li>"+
                        "<li style='color: green;font-size: 1.3em;'>Recoverd:   "+str(recovered_case.iloc[i,-1])+"</li>"+
                        "<li style='color: red;font-size: 1.3em;'>Death:   "+str(death_case.iloc[i-1,-1])+"</li>"+
                        "<li style='color: #763759;font-size: 1.3em;'>Active:   "+str((confirmed_case.iloc[i,-1])-((death_case.iloc[3-i,-1])+(recovered_case.iloc[i,-1])))+"</li>"+
                        #str( "<br><b>mylink</b> <a href="+"/page-1"+">click</a>")+ 
                    "</ul> </div>",
            ).add_to(world_map)
    return world_map
mouse()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrap
# ...

# %%
loc_map =mouse()

loc_map.save("heet.html")
map_view = html.Div([
    html.Iframe(id='map',srcDoc=open('heet.html','r').read(),width='100%',height='600')
])

# %%
app.run_server(host= '192.168.0.101',debug=False)
# Out:
# Dash is running on http://192.168.0.101:8050/
#
# Dash is running on http://192.168.0.101:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://192.168.0.101:8050/ (Press CTRL+C to quit)
# 192.168.0.101 - - [11/Apr/2021 06:38:32] "GET / HTTP/1.1" 200 -
# 192.168.0.101 - - [11/Apr/2021 06:38:33] "GET /_dash-layout HTTP/1.1" 200 -
# 192.168.0.101 - - [11/Apr/2021 06:38:33] "GET /_dash-dependencies HTTP/1.1" 200 -
# 192.168.0.101 - - [11/Apr/2021 06:38:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.101 - - [11/Apr/2021 06:38:33] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.101 - - [11/Apr/2021 06:39:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 192.168.0.101 - - [11/Apr/2021 06:40:01] "POST /_dash-update-component HTTP/1.1" 200 -
# ...
